# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/FinancialMarketData.xlsx - EWS.csv');
df
# Out:
#       Y       Data  XAU BGNL  ECSURPUS    BDIY       CRY      DXY     JPY  \
# 0     0  1/11/2000    283.25     0.077  1388.0  157.2600  100.560  105.86
# 1     0  1/18/2000    287.65     0.043  1405.0  165.0100  101.860  105.47
# 2     0  1/25/2000    287.15     0.135  1368.0  167.2400  102.410  106.04
# 3     0   2/1/2000    282.75     0.191  1311.0  166.8500  104.920  107.85
# 4     1   2/8/2000    298.40     0.312  1277.0  165.4300  104.220  109.30
# ...  ..        ...       ...       ...     ...       ...      ...     ...
# 1106  0  3/23/2021   1727.96     0.339  2271.0  184.5022   92.336  108.72
# 1107  0  3/30/2021   1685.56     0.303  2103.0  184.8741   93.297  110.29
# 1108  0   4/6/2021   1743.28     0.440  2092.0  185.8393   92.335  109.88
# 1109  0  4/13/2021   1742.69     0.467  2140.0  188.1368   91.852  109.19
# 1110  0  4/20/2021   1779.72     0.492  2432.0  193.8035   91.147  108.09
#
#          GBP    Cl1  ...  LP01TREU  EMUSTRUU  LF94TRUU     MXUS    MXEU  \
# ...

# %%
df.describe()
# Out:
#                  Y     XAU BGNL     ECSURPUS          BDIY          CRY  \
# count  1111.000000  1111.000000  1111.000000   1111.000000  1111.000000
# mean      0.213321   987.463744     0.036153   2259.860486   245.247670
# std       0.409837   494.623740     0.349453   2017.811888    68.278066
# min       0.000000   256.680000    -0.974000    291.000000   106.293000
# 25%       0.000000   433.740000    -0.191000    990.000000   184.705550
# 50%       0.000000  1137.800000     0.035000   1518.000000   234.560000
# 75%       0.000000  1324.825000     0.260500   2685.500000   301.539500
# max       1.000000  2006.910000     0.991000  11793.000000   467.570000
#
#                DXY          JPY          GBP          Cl1          VIX  ...  \
# count  1111.000000  1111.000000  1111.000000  1111.000000  1111.000000  ...
# mean     90.934982   106.605734     1.569661    60.708101    19.992169  ...
# std      11.379095    12.840754     0.212344    25.900813     8.642157  ...
# ...

# %%
df.dropna()
# Out:
#       Y       Data  XAU BGNL  ECSURPUS    BDIY       CRY      DXY     JPY  \
# 0     0  1/11/2000    283.25     0.077  1388.0  157.2600  100.560  105.86
# 1     0  1/18/2000    287.65     0.043  1405.0  165.0100  101.860  105.47
# 2     0  1/25/2000    287.15     0.135  1368.0  167.2400  102.410  106.04
# 3     0   2/1/2000    282.75     0.191  1311.0  166.8500  104.920  107.85
# 4     1   2/8/2000    298.40     0.312  1277.0  165.4300  104.220  109.30
# ...  ..        ...       ...       ...     ...       ...      ...     ...
# 1106  0  3/23/2021   1727.96     0.339  2271.0  184.5022   92.336  108.72
# 1107  0  3/30/2021   1685.56     0.303  2103.0  184.8741   93.297  110.29
# 1108  0   4/6/2021   1743.28     0.440  2092.0  185.8393   92.335  109.88
# 1109  0  4/13/2021   1742.69     0.467  2140.0  188.1368   91.852  109.19
# 1110  0  4/20/2021   1779.72     0.492  2432.0  193.8035   91.147  108.09
#
#          GBP    Cl1  ...  LP01TREU  EMUSTRUU  LF94TRUU     MXUS    MXEU  \
# ...

# %%
sns.countplot(x='Y',data = df)
plt.title("Counter Plot of Anomaly")
# Out:
# Text(0.5, 1.0, 'Counter Plot of Anomaly')

# %%
# sns.scatterplot(x='DXY',y='Y',data=df)
# plt.title("Scatter Plot of DXY vs Y")

# %%
features =df.drop('Y',axis = 1)
features
# Out:
#            Data  XAU BGNL  ECSURPUS    BDIY       CRY      DXY     JPY  \
# 0     1/11/2000    283.25     0.077  1388.0  157.2600  100.560  105.86
# 1     1/18/2000    287.65     0.043  1405.0  165.0100  101.860  105.47
# 2     1/25/2000    287.15     0.135  1368.0  167.2400  102.410  106.04
# 3      2/1/2000    282.75     0.191  1311.0  166.8500  104.920  107.85
# 4      2/8/2000    298.40     0.312  1277.0  165.4300  104.220  109.30
# ...         ...       ...       ...     ...       ...      ...     ...
# 1106  3/23/2021   1727.96     0.339  2271.0  184.5022   92.336  108.72
# 1107  3/30/2021   1685.56     0.303  2103.0  184.8741   93.297  110.29
# 1108   4/6/2021   1743.28     0.440  2092.0  185.8393   92.335  109.88
# 1109  4/13/2021   1742.69     0.467  2140.0  188.1368   91.852  109.19
# 1110  4/20/2021   1779.72     0.492  2432.0  193.8035   91.147  108.09
#
#          GBP    Cl1    VIX  ...  LP01TREU  EMUSTRUU  LF94TRUU     MXUS  \
# ...

# %%
target = df['Y']
target
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 1106    0
# 1107    0
# 1108    0
# 1109    0
# 1110    0
# Name: Y, Length: 1111, dtype: int64

# %%
# feature_columns = features.columns.tolist()  # All columns except 'Y'

# # Pair plot for features vs target
# sns.pairplot(df, y_vars=['Y'], x_vars=feature_columns, height=3, aspect=1.5)
# plt.suptitle("Scatter Plots of Features vs Target", y=1.02)
# plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# %%
features['Data'] = pd.to_datetime(features['Data'])

features['year'] = features['Data'].dt.year
features['month'] = features['Data'].dt.month
features['day'] = features['Data'].dt.day
features['day_of_week'] = features['Data'].dt.dayofweek

features.drop('Data',axis = 1,inplace = True)

# %%
# features.drop(['LUMSTRUU','year','day_of_week'],axis = 1,inplace = True)

# %%
features
# Out:
#       XAU BGNL  ECSURPUS    BDIY       CRY      DXY     JPY     GBP    Cl1  \
# 0       283.25     0.077  1388.0  157.2600  100.560  105.86  1.6460  25.77
# 1       287.65     0.043  1405.0  165.0100  101.860  105.47  1.6380  28.85
# 2       287.15     0.135  1368.0  167.2400  102.410  106.04  1.6500  28.28
# 3       282.75     0.191  1311.0  166.8500  104.920  107.85  1.6110  28.22
# 4       298.40     0.312  1277.0  165.4300  104.220  109.30  1.6110  28.02
# ...        ...       ...     ...       ...      ...     ...     ...    ...
# 1106   1727.96     0.339  2271.0  184.5022   92.336  108.72  1.3760  57.76
# 1107   1685.56     0.303  2103.0  184.8741   93.297  110.29  1.3719  60.55
# 1108   1743.28     0.440  2092.0  185.8393   92.335  109.88  1.3822  59.33
# 1109   1742.69     0.467  2140.0  188.1368   91.852  109.19  1.3737  60.18
# 1110   1779.72     0.492  2432.0  193.8035   91.147  108.09  1.3951  62.50
#
# ...

# %%
X_train,X_test,Y_train,Y_test = train_test_split(features,target,test_size=0.2,random_state = 42)

# %%
X_test
# Out:
#      XAU BGNL  ECSURPUS     BDIY      CRY      DXY     JPY    GBP     Cl1  \
# 436    921.90    -0.160  11793.0  427.230   72.405  103.71  1.971  129.07
# 539   1219.85     0.517   3822.0  264.950   84.467   93.07  1.499   76.37
# 56     263.05    -0.405   1472.0  200.690  110.700  114.93  1.458   30.35
# 695   1451.88    -0.191    889.0  288.986   82.253   99.03  1.548   95.62
# 722   1275.87     0.073   1543.0  273.427   81.192   99.53  1.591   93.04
# ..        ...       ...      ...      ...      ...     ...    ...     ...
# 346    611.41    -0.275   3750.0  327.730   84.960  116.97  1.891   69.71
# 361    627.81    -0.650   4270.0  310.830   82.940  117.09  1.965   61.02
# 243    398.55    -0.145   4018.0  268.600   89.230  109.31  1.774   43.31
# 793   1193.70    -0.741    597.0  215.531   97.193  119.67  1.487   47.51
# 874   1256.14     0.033    922.0  189.160   97.690  103.46  1.216   50.79
#
#        VIX  USGG30YR  ...    MXEU     MXJP     MXBR     MXRU     MXIN   MXCN  \
# ...

# %%
Y_test
# Out:
# 436    0
# 539    1
# 56     1
# 695    0
# 722    0
#       ..
# 346    0
# 361    0
# 243    0
# 793    0
# 874    0
# Name: Y, Length: 223, dtype: int64

# %%
X_train
# Out:
#       XAU BGNL  ECSURPUS    BDIY       CRY      DXY     JPY     GBP    Cl1  \
# 865    1340.08     0.195   631.0  181.4300   96.183  101.95  1.3010  42.77
# 993    1283.70    -0.176  1036.0  178.9900   96.303  109.32  1.2960  52.57
# 928    1276.52     0.168  1588.0  185.8240   93.772  113.87  1.3130  52.47
# 780    1178.25     0.212   788.0  238.6120   90.064  120.62  1.5520  57.12
# 734    1251.32    -0.093  1084.0  286.4370   81.121  101.62  1.6320  97.19
# ...        ...       ...     ...       ...      ...     ...     ...    ...
# 466     839.00    -0.703   828.0  226.3200   80.683   90.06  1.5290  43.60
# 121     311.45     0.326  1018.0  163.5400  113.920  128.02  1.4670  26.63
# 1044   1543.58    -0.086   763.0  183.6410   97.372  110.10  1.3020  58.23
# 1095   1950.23     0.241  1418.0  171.7048   89.436  102.65  1.3633  49.93
# 860    1355.01    -0.099   692.0  189.6600   96.166  101.52  1.3050  46.60
#
# ...

# %%
scalar = StandardScaler()

X_train = scalar.fit_transform(X_train)
X_test = scalar.fit_transform(X_test)

# %%
X_train[0]
# Out:
# array([ 0.69444386,  0.45816213, -0.79925167, -0.90932775,  0.46714485,
#        -0.36811659, -1.24172015, -0.68081812, -0.96856785, -1.36252949,
#        -1.26288058, -0.7397763 , -0.71190774, -0.68567167, -1.43303782,
#        -1.33152041, -1.07763069, -0.97677662, -1.81858982, -1.71650701,
#        -1.26224478, -1.73526361, -1.49865528, -1.12436661, -1.58448481,
#        -1.58127945, -1.01932414,  0.99665597,  1.07440828,  1.00917389,
#         0.90507121,  0.94287845,  1.04356188,  1.01968494,  0.87367152,
#         0.63417262,  0.39687565,  0.04932911, -0.2053894 , -0.50634989,
#         0.87810412,  0.19468193,  0.91700281,  0.44083827, -0.7635134 ,
#         0.        ])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics  import accuracy_score,confusion_matrix,classification_report

import pickle

from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier # RandomForest
from sklearn.tree import DecisionTreeClassifier # DecisionTree model
from sklearn.svm import SVC # Support Vector machine model
from sklearn.naive_bayes import GaussianNB # Naive Bayes model
from sklearn.neighbors import KNeighborsClassifier # K Nearest Neighbors model
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import StackingClassifier

# %%
LogReg_model = LogisticRegression()
LogReg_model.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
Logreg_predictions = LogReg_model.predict(X_test)

# %%
LogReg_accuracy = accuracy_score(Y_test,Logreg_predictions)
LogReg_accuracy
# Out:
# 0.8834080717488789

# %%
def evaluate_and_save_model(model,X_train,X_test,Y_train,Y_test,file_name):
  model.fit(X_train,Y_train)
  model_predictions = model.predict(X_test)
  model_accuracy = accuracy_score(Y_test,model_predictions)
  print(f"{model.__class__.__name__} Accuracy : {model_accuracy:.4f}")
  print(f"\nClassification Report :\n {classification_report(Y_test,model_predictions)}")



  with open(file_name, "wb") as file:
    pickle.dump(model,file)

  print(f"model saved as {file_name}")
  print("*************************************************\n\n")

# %%
# !pip install scikit-learn==1.2.2

# %%
xgb_model = XGBClassifier(random_state=42)
evaluate_and_save_model(xgb_model,X_train,X_test,Y_train,Y_test,"xgb_model.pkl")

dt_model = DecisionTreeClassifier(random_state = 42)
evaluate_and_save_model(dt_model,X_train,X_test,Y_train,Y_test,"dt_model.pkl")

svm_model = SVC(random_state = 42)
evaluate_and_save_model(svm_model,X_train,X_test,Y_train,Y_test,"svm_model.pkl")

nb_model = GaussianNB()
evaluate_and_save_model(nb_model,X_train,X_test,Y_train,Y_test,"nb_model.pkl")

k_neighbors_model = KNeighborsClassifier()
evaluate_and_save_model(k_neighbors_model,X_train,X_test,Y_train,Y_test,"k_neighbors_model.pkl")

gb_model = GradientBoostingClassifier(random_state = 42)
evaluate_and_save_model(gb_model,X_train,X_test,Y_train,Y_test,"gb_model.pkl")

#Stacking Classifer model
estimators = [
    ('xgb',XGBClassifier(random_state=42)),
    ('svm',SVC(random_state = 42)),
    ('nb',GaussianNB()),
    ('k_neighbors',KNeighborsClassifier()),
    ('gb',GradientBoostingClassifier(random_state = 42))
]

final_estimator = make_pipeline(StandardScaler(),LogisticRegression(max_iter = 500,random_state = 42))

stacking_model = StackingClassifier(estimators = estimators,final_estimator = final_estimator,passthrough=True)
evaluate_and_save_model(stacking_model,X_train,X_test,Y_train,Y_test,"stacking_model.pkl")
# Out:
# XGBClassifier Accuracy : 0.9013
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94       177
#            1       0.79      0.72      0.75        46
#
#     accuracy                           0.90       223
#    macro avg       0.86      0.83      0.84       223
# weighted avg       0.90      0.90      0.90       223
#
# model saved as xgb_model.pkl
# *************************************************
#
#
# DecisionTreeClassifier Accuracy : 0.7848
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86       177
#            1       0.48      0.48      0.48        46
#
#     accuracy                           0.78       223
#    macro avg       0.67      0.67      0.67       223
# weighted avg       0.78      0.78      0.78       223
#
# model saved as dt_model.pkl
# *************************************************
#
#
# ...

# %%
feature_importances = xgb_model.feature_importances_
feature_names = features.columns

# %%
print(f"Length of feature_names: {len(feature_names)}")
print(f"Length of feature_importances: {len(feature_importances)}")
min_len = min(len(feature_names), len(feature_importances))
feature_importances = feature_importances[:min_len]
feature_names = feature_names[:min_len]
feature_importances
# Out:
# Length of feature_names: 46
# Length of feature_importances: 46
# array([0.02771141, 0.01500451, 0.02029295, 0.01184274, 0.02248471,
#        0.02291045, 0.02285675, 0.01133693, 0.14448063, 0.01878949,
#        0.00852568, 0.01081315, 0.01722572, 0.01528391, 0.02526153,
#        0.00312526, 0.04510937, 0.01226495, 0.03571407, 0.1271448 ,
#        0.01527741, 0.01197733, 0.00896569, 0.01851447, 0.02678766,
#        0.01294753, 0.00510623, 0.        , 0.00928551, 0.02614615,
#        0.05089012, 0.03010909, 0.01480972, 0.00860717, 0.00825684,
#        0.01152281, 0.03081396, 0.02455955, 0.01477371, 0.01284008,
#        0.01018684, 0.01153285, 0.        , 0.00724094, 0.01066926,
#        0.        ], dtype=float32)

# %%
feature_names
# Out:
# Index(['XAU BGNL', 'ECSURPUS', 'BDIY', 'CRY', 'DXY', 'JPY', 'GBP', 'Cl1',
#        'VIX', 'USGG30YR', 'GT10', 'USGG2YR', 'USGG3M', 'US0001M', 'GTDEM30Y',
#        'GTDEM10Y', 'GTDEM2Y', 'EONIA', 'GTITL30YR', 'GTITL10YR', 'GTITL2YR',
#        'GTJPY30YR', 'GTJPY10YR', 'GTJPY2YR', 'GTGBP30Y', 'GTGBP20Y', 'GTGBP2Y',
#        'LUMSTRUU', 'LMBITR', 'LUACTRUU', 'LF98TRUU', 'LG30TRUU', 'LP01TREU',
#        'EMUSTRUU', 'LF94TRUU', 'MXUS', 'MXEU', 'MXJP', 'MXBR', 'MXRU', 'MXIN',
#        'MXCN', 'year', 'month', 'day', 'day_of_week'],
#       dtype='object')

# %%
feature_importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': feature_importances

}).sort_values('Importance',ascending = False)
feature_importance_df
# Out:
#         Feature  Importance
# 8           VIX    0.144481
# 19    GTITL10YR    0.127145
# 30     LF98TRUU    0.050890
# 16      GTDEM2Y    0.045109
# 18    GTITL30YR    0.035714
# 36         MXEU    0.030814
# 31     LG30TRUU    0.030109
# 0      XAU BGNL    0.027711
# 24     GTGBP30Y    0.026788
# 29     LUACTRUU    0.026146
# 14     GTDEM30Y    0.025262
# 37         MXJP    0.024560
# 5           JPY    0.022910
# 6           GBP    0.022857
# 4           DXY    0.022485
# 2          BDIY    0.020293
# 9      USGG30YR    0.018789
# 23     GTJPY2YR    0.018514
# 12       USGG3M    0.017226
# 13      US0001M    0.015284
# 20     GTITL2YR    0.015277
# 1      ECSURPUS    0.015005
# 32     LP01TREU    0.014810
# 38         MXBR    0.014774
# 25     GTGBP20Y    0.012948
# 39         MXRU    0.012840
# 17        EONIA    0.012265
# 21    GTJPY30YR    0.011977
# 3           CRY    0.011843
# 41         MXCN    0.011533
# 35         MXUS    0.011523
# 7           Cl1    0.011337
# ...

# %%
sns.barplot(x='Feature',y='Importance',data = feature_importance_df,width = 0.9)
plt.title("Feature Importance")
plt.xticks(rotation = 90)
plt.figure(figsize=(10,6))
plt.tight_layout()
plt.show()

# %%
#Next techniques is SMOTE - Synthetic Minority Oversampling Technique
# !pip install -U scikit-learn==1.2.2 imbalanced-learn==0.10.1

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42)

# %%
X_resampled,Y_resampled = smote.fit_resample(X_train,Y_train)

# %%
evaluate_and_save_model(xgb_model,X_resampled,X_test,Y_resampled,Y_test,"xgboost_smote_model.pkl")
# Out:
# XGBClassifier Accuracy : 0.8789
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.95      0.90      0.92       177
#            1       0.67      0.80      0.73        46
#
#     accuracy                           0.88       223
#    macro avg       0.81      0.85      0.83       223
# weighted avg       0.89      0.88      0.88       223
#
# model saved as xgboost_smote_model.pkl
# *************************************************

# %%
from sklearn.ensemble import VotingClassifier
voting_clf = VotingClassifier(
    estimators = [('xgb',XGBClassifier(random_state=42)),
    ('svm',SVC(random_state = 42,probability = True)),
    ('nb',GaussianNB()),
    ('k_neighbors',KNeighborsClassifier()),
    ('gb',GradientBoostingClassifier(random_state = 42))],
    voting = 'soft'
)

# %%
evaluate_and_save_model(voting_clf,X_resampled,X_test,Y_resampled,Y_test,"voting_clf.pkl")
# Out:
# VotingClassifier Accuracy : 0.8565
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.94      0.88      0.91       177
#            1       0.62      0.78      0.69        46
#
#     accuracy                           0.86       223
#    macro avg       0.78      0.83      0.80       223
# weighted avg       0.87      0.86      0.86       223
#
# model saved as voting_clf.pkl
# *************************************************
